# %%
#Install dependencies
# %pip install anthropic python-dotenv

# %%
#Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content" : text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content" : text}
    messages.append(assistant_message)

def chat(messages, system = None, temperature = 1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea",
    )
answer = chat(messages, temperature=1.0)

answer
# Out:
# "# Movie Idea\n\nA cynical time-traveling repairman discovers that every small mistake he fixes creates catastrophic consequences in the future, forcing him to decide whether to let humanity's tragic destiny unfold or risk erasing existence itself."
