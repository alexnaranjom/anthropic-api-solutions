# %%
#Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (0.97.0)
# Requirement already satisfied: python-dotenv in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: sniffio in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.25.0->anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\alexn\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content" : text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content" : text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []

#Add in the initial user question of "Define quantum computing in one sentence"
add_user_message(messages, "Define quantum computing in one sentence")

# Pss the list of messages into 'chat' to get an answer
answer = chat(messages)
print(answer)

# Take the answer and add it as an assitant message into our list
add_assistant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Tell me another sentence")

# Call chat again with the list of messages to get a final answer
answer = chat(messages)
print(answer)
# Out:
# Quantum computing is a type of computation that uses quantum bits (qubits) to process information by exploiting quantum mechanical phenomena like superposition and entanglement, enabling certain problems to be solved exponentially faster than classical computers.
# Unlike classical computers that process information as definite 0s or 1s, quantum computers can exploit superposition to evaluate multiple possibilities simultaneously, making them particularly powerful for problems in cryptography, optimization, and drug discovery.

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a type of computation that uses quantum bits (qubits) to process information by exploiting quantum mechanical phenomena like superposition and entanglement, enabling certain problems to be solved exponentially faster than classical computers.'},
#  {'role': 'user', 'content': 'Tell me another sentence'}]

# %%
# Make ana initial list of messages
messages = []

# Use a 'while True' loop to run the cathbot forever
for i in range(3):
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add user input to the list of messages
    add_user_message(messages, user_input)
    
    # Call Claude with the 'chat' function
    response = chat(messages)
    
    # Add generated text to the list of messages
    add_assistant_message(messages, response)

    # Print the generated Text
    print("-----", response, "----", sep="\n")
# Out:
# > what is 1+1?
# -----
# 1 + 1 = 2
# ----
# > And 2 more
# -----
# 2 + 2 = 4
# ----
# > And 3 more
# -----
# 4 + 3 = 7
# ----
